# %%
import os
from urllib.request import urlretrieve
from ftplib import FTP
import gzip
import xml.etree.ElementTree as ET
import pandas as pd
from concurrent.futures import ProcessPoolExecutor, as_completed
from tqdm import tqdm
import csv
from datasets import load_dataset, Dataset, DatasetDict

# %%
# Settings
ftp_host = "ftp.ncbi.nlm.nih.gov"
ftp_dir = "/pubmed/baseline"
download_dir = "../data/pubmed_baseline"
max_files = 300  # ← Limit how many files to download

gz_dir = download_dir
min_words = 20  # Minimum number of words in abstract
max_workers = 8  # Adjust based on your CPU
output_csv = download_dir + "/pubmed_filtered.csv"
output_csv_small = download_dir + "/pubmed_filtered_small.csv"
train_csv = download_dir + "/pubmed_train.csv"
test_csv = download_dir + "/pubmed_test.csv"
val_csv = download_dir + "/pubmed_val.csv"
train_tokenized = download_dir + "/pubmed_train"
test_tokenized = download_dir + "/pubmed_test"
val_tokenized = download_dir + "/pubmed_val"

train_size = 1_000_000
test_size = 3000
val_size = 200

max_len = 512

# %%
os.makedirs(download_dir, exist_ok=True)

# Connect to FTP and list files
ftp = FTP(ftp_host)
ftp.login()
ftp.cwd(ftp_dir)
files = []
ftp.retrlines("NLST", files.append)
ftp.quit()

# Filter .gz files and limit number
gz_files = sorted([f for f in files if f.endswith(".gz")])[:max_files]
gz_files
# Out:
# ['pubmed25n0001.xml.gz',
#  'pubmed25n0002.xml.gz',
#  'pubmed25n0003.xml.gz',
#  'pubmed25n0004.xml.gz',
#  'pubmed25n0005.xml.gz',
#  'pubmed25n0006.xml.gz',
#  'pubmed25n0007.xml.gz',
#  'pubmed25n0008.xml.gz',
#  'pubmed25n0009.xml.gz',
#  'pubmed25n0010.xml.gz',
#  'pubmed25n0011.xml.gz',
#  'pubmed25n0012.xml.gz',
#  'pubmed25n0013.xml.gz',
#  'pubmed25n0014.xml.gz',
#  'pubmed25n0015.xml.gz',
#  'pubmed25n0016.xml.gz',
#  'pubmed25n0017.xml.gz',
#  'pubmed25n0018.xml.gz',
#  'pubmed25n0019.xml.gz',
#  'pubmed25n0020.xml.gz',
#  'pubmed25n0021.xml.gz',
#  'pubmed25n0022.xml.gz',
#  'pubmed25n0023.xml.gz',
#  'pubmed25n0024.xml.gz',
#  'pubmed25n0025.xml.gz',
#  'pubmed25n0026.xml.gz',
#  'pubmed25n0027.xml.gz',
#  'pubmed25n0028.xml.gz',
#  'pubmed25n0029.xml.gz',
#  'pubmed25n0030.xml.gz',
#  'pubmed25n0031.xml.gz',
#  'pubmed25n0032.xml.gz',
#  'pubmed25n0033.xml.gz',
#  'pubmed25n0034.xml.gz',
#  'pubmed25n0035.xml.gz',
#  'pubmed25n0036.xml.gz',
#  'pubmed25n0037.xml.gz',
#  'pubmed25n0038.xml.gz',
#  'pubmed25n0039.xml.gz',
#  'pubmed25n0040.xml.gz',
#  'pubmed25n0041.xml.gz',
#  'pubmed25n0042.xml.gz',
#  'pubmed25n0043.xml.gz',
#  'pubmed25n0044.xml.gz',
#  'pubmed25n0045.xml.gz',
#  'pubmed25n0046.xml.gz',
#  'pubmed25n0047.xml.gz',
#  'pubmed25n0048.xml.gz',
#  'pubmed25n0049.xml.gz',
#  'pubmed25n0050.xml.gz',
#  'pubmed25n0051.xml.gz',
#  'pubmed25n0052.xml.gz',
#  'pubmed25n0053.xml.gz',
#  'pubmed25n0054.xml.gz',
#  'pubmed25n0055.xml.gz',
#  'pubmed25n0056.xml.gz',
#  'pubmed25n0057.xml.gz',
#  'pubmed25n0058.xml.gz',
#  'pubmed25n0059.xml.gz',
#  'pubmed25n0060.xml.gz',
#  'pubmed25n0061.xml.gz',
#  'pubmed25n0062.xml.gz',
#  'pubmed25n0063.xml.gz',
#  'pubmed25n0064.xml.gz',
#  'pubmed25n0065.xml.gz',
#  'pubmed25n0066.xml.gz',
#  'pubmed25n0067.xml.gz',
#  'pubmed25n0068.xml.gz',
#  'pubmed25n0069.xml.gz',
#  'pubmed25n0070.xml.gz',
#  'pubmed25n0071.xml.gz',
#  'pubmed25n0072.xml.gz',
#  'pubmed25n0073.xml.gz',
#  'pubmed25n0074.xml.gz',
#  'pubmed25n0075.xml.gz',
#  'pubmed25n0076.xml.gz',
#  'pubmed25n0077.xml.gz',
#  'pubmed25n0078.xml.gz',
#  'pubmed25n0079.xml.gz',
#  'pubmed25n0080.xml.gz',
#  'pubmed25n0081.xml.gz',
#  'pubmed25n0082.xml.gz',
#  'pubmed25n0083.xml.gz',
#  'pubmed25n0084.xml.gz',
#  'pubmed25n0085.xml.gz',
#  'pubmed25n0086.xml.gz',
#  'pubmed25n0087.xml.gz',
#  'pubmed25n0088.xml.gz',
#  'pubmed25n0089.xml.gz',
#  'pubmed25n0090.xml.gz',
#  'pubmed25n0091.xml.gz',
#  'pubmed25n0092.xml.gz',
#  'pubmed25n0093.xml.gz',
#  'pubmed25n0094.xml.gz',
#  'pubmed25n0095.xml.gz',
#  'pubmed25n0096.xml.gz',
#  'pubmed25n0097.xml.gz',
#  'pubmed25n0098.xml.gz',
#  'pubmed25n0099.xml.gz',
#  'pubmed25n0100.xml.gz',
#  'pubmed25n0101.xml.gz',
#  'pubmed25n0102.xml.gz',
#  'pubmed25n0103.xml.gz',
#  'pubmed25n0104.xml.gz',
#  'pubmed25n0105.xml.gz',
#  'pubmed25n0106.xml.gz',
#  'pubmed25n0107.xml.gz',
#  'pubmed25n0108.xml.gz',
#  'pubmed25n0109.xml.gz',
#  'pubmed25n0110.xml.gz',
#  'pubmed25n0111.xml.gz',
#  'pubmed25n0112.xml.gz',
#  'pubmed25n0113.xml.gz',
#  'pubmed25n0114.xml.gz',
#  'pubmed25n0115.xml.gz',
#  'pubmed25n0116.xml.gz',
#  'pubmed25n0117.xml.gz',
#  'pubmed25n0118.xml.gz',
#  'pubmed25n0119.xml.gz',
#  'pubmed25n0120.xml.gz',
#  'pubmed25n0121.xml.gz',
#  'pubmed25n0122.xml.gz',
#  'pubmed25n0123.xml.gz',
#  'pubmed25n0124.xml.gz',
#  'pubmed25n0125.xml.gz',
#  'pubmed25n0126.xml.gz',
#  'pubmed25n0127.xml.gz',
#  'pubmed25n0128.xml.gz',
#  'pubmed25n0129.xml.gz',
#  'pubmed25n0130.xml.gz',
#  'pubmed25n0131.xml.gz',
#  'pubmed25n0132.xml.gz',
#  'pubmed25n0133.xml.gz',
#  'pubmed25n0134.xml.gz',
#  'pubmed25n0135.xml.gz',
#  'pubmed25n0136.xml.gz',
#  'pubmed25n0137.xml.gz',
#  'pubmed25n0138.xml.gz',
#  'pubmed25n0139.xml.gz',
#  'pubmed25n0140.xml.gz',
#  'pubmed25n0141.xml.gz',
#  'pubmed25n0142.xml.gz',
#  'pubmed25n0143.xml.gz',
#  'pubmed25n0144.xml.gz',
#  'pubmed25n0145.xml.gz',
#  'pubmed25n0146.xml.gz',
#  'pubmed25n0147.xml.gz',
#  'pubmed25n0148.xml.gz',
#  'pubmed25n0149.xml.gz',
#  'pubmed25n0150.xml.gz',
#  'pubmed25n0151.xml.gz',
#  'pubmed25n0152.xml.gz',
#  'pubmed25n0153.xml.gz',
#  'pubmed25n0154.xml.gz',
#  'pubmed25n0155.xml.gz',
#  'pubmed25n0156.xml.gz',
#  'pubmed25n0157.xml.gz',
#  'pubmed25n0158.xml.gz',
#  'pubmed25n0159.xml.gz',
#  'pubmed25n0160.xml.gz',
#  'pubmed25n0161.xml.gz',
#  'pubmed25n0162.xml.gz',
#  'pubmed25n0163.xml.gz',
#  'pubmed25n0164.xml.gz',
#  'pubmed25n0165.xml.gz',
#  'pubmed25n0166.xml.gz',
#  'pubmed25n0167.xml.gz',
#  'pubmed25n0168.xml.gz',
#  'pubmed25n0169.xml.gz',
#  'pubmed25n0170.xml.gz',
#  'pubmed25n0171.xml.gz',
#  'pubmed25n0172.xml.gz',
#  'pubmed25n0173.xml.gz',
#  'pubmed25n0174.xml.gz',
#  'pubmed25n0175.xml.gz',
#  'pubmed25n0176.xml.gz',
#  'pubmed25n0177.xml.gz',
#  'pubmed25n0178.xml.gz',
#  'pubmed25n0179.xml.gz',
#  'pubmed25n0180.xml.gz',
#  'pubmed25n0181.xml.gz',
#  'pubmed25n0182.xml.gz',
#  'pubmed25n0183.xml.gz',
#  'pubmed25n0184.xml.gz',
#  'pubmed25n0185.xml.gz',
#  'pubmed25n0186.xml.gz',
#  'pubmed25n0187.xml.gz',
#  'pubmed25n0188.xml.gz',
#  'pubmed25n0189.xml.gz',
#  'pubmed25n0190.xml.gz',
#  'pubmed25n0191.xml.gz',
#  'pubmed25n0192.xml.gz',
#  'pubmed25n0193.xml.gz',
#  'pubmed25n0194.xml.gz',
#  'pubmed25n0195.xml.gz',
#  'pubmed25n0196.xml.gz',
#  'pubmed25n0197.xml.gz',
#  'pubmed25n0198.xml.gz',
#  'pubmed25n0199.xml.gz',
#  'pubmed25n0200.xml.gz',
#  'pubmed25n0201.xml.gz',
#  'pubmed25n0202.xml.gz',
#  'pubmed25n0203.xml.gz',
#  'pubmed25n0204.xml.gz',
#  'pubmed25n0205.xml.gz',
#  'pubmed25n0206.xml.gz',
#  'pubmed25n0207.xml.gz',
#  'pubmed25n0208.xml.gz',
#  'pubmed25n0209.xml.gz',
#  'pubmed25n0210.xml.gz',
#  'pubmed25n0211.xml.gz',
#  'pubmed25n0212.xml.gz',
#  'pubmed25n0213.xml.gz',
#  'pubmed25n0214.xml.gz',
#  'pubmed25n0215.xml.gz',
#  'pubmed25n0216.xml.gz',
#  'pubmed25n0217.xml.gz',
#  'pubmed25n0218.xml.gz',
#  'pubmed25n0219.xml.gz',
#  'pubmed25n0220.xml.gz',
#  'pubmed25n0221.xml.gz',
#  'pubmed25n0222.xml.gz',
#  'pubmed25n0223.xml.gz',
#  'pubmed25n0224.xml.gz',
#  'pubmed25n0225.xml.gz',
#  'pubmed25n0226.xml.gz',
#  'pubmed25n0227.xml.gz',
#  'pubmed25n0228.xml.gz',
#  'pubmed25n0229.xml.gz',
#  'pubmed25n0230.xml.gz',
#  'pubmed25n0231.xml.gz',
#  'pubmed25n0232.xml.gz',
#  'pubmed25n0233.xml.gz',
#  'pubmed25n0234.xml.gz',
#  'pubmed25n0235.xml.gz',
#  'pubmed25n0236.xml.gz',
#  'pubmed25n0237.xml.gz',
#  'pubmed25n0238.xml.gz',
#  'pubmed25n0239.xml.gz',
#  'pubmed25n0240.xml.gz',
#  'pubmed25n0241.xml.gz',
#  'pubmed25n0242.xml.gz',
#  'pubmed25n0243.xml.gz',
#  'pubmed25n0244.xml.gz',
#  'pubmed25n0245.xml.gz',
#  'pubmed25n0246.xml.gz',
#  'pubmed25n0247.xml.gz',
#  'pubmed25n0248.xml.gz',
#  'pubmed25n0249.xml.gz',
#  'pubmed25n0250.xml.gz',
#  'pubmed25n0251.xml.gz',
#  'pubmed25n0252.xml.gz',
#  'pubmed25n0253.xml.gz',
#  'pubmed25n0254.xml.gz',
#  'pubmed25n0255.xml.gz',
#  'pubmed25n0256.xml.gz',
#  'pubmed25n0257.xml.gz',
#  'pubmed25n0258.xml.gz',
#  'pubmed25n0259.xml.gz',
#  'pubmed25n0260.xml.gz',
#  'pubmed25n0261.xml.gz',
#  'pubmed25n0262.xml.gz',
#  'pubmed25n0263.xml.gz',
#  'pubmed25n0264.xml.gz',
#  'pubmed25n0265.xml.gz',
#  'pubmed25n0266.xml.gz',
#  'pubmed25n0267.xml.gz',
#  'pubmed25n0268.xml.gz',
#  'pubmed25n0269.xml.gz',
#  'pubmed25n0270.xml.gz',
#  'pubmed25n0271.xml.gz',
#  'pubmed25n0272.xml.gz',
#  'pubmed25n0273.xml.gz',
#  'pubmed25n0274.xml.gz',
#  'pubmed25n0275.xml.gz',
#  'pubmed25n0276.xml.gz',
#  'pubmed25n0277.xml.gz',
#  'pubmed25n0278.xml.gz',
#  'pubmed25n0279.xml.gz',
#  'pubmed25n0280.xml.gz',
#  'pubmed25n0281.xml.gz',
#  'pubmed25n0282.xml.gz',
#  'pubmed25n0283.xml.gz',
#  'pubmed25n0284.xml.gz',
#  'pubmed25n0285.xml.gz',
#  'pubmed25n0286.xml.gz',
#  'pubmed25n0287.xml.gz',
#  'pubmed25n0288.xml.gz',
#  'pubmed25n0289.xml.gz',
#  'pubmed25n0290.xml.gz',
#  'pubmed25n0291.xml.gz',
#  'pubmed25n0292.xml.gz',
#  'pubmed25n0293.xml.gz',
#  'pubmed25n0294.xml.gz',
#  'pubmed25n0295.xml.gz',
#  'pubmed25n0296.xml.gz',
#  'pubmed25n0297.xml.gz',
#  'pubmed25n0298.xml.gz',
#  'pubmed25n0299.xml.gz',
#  'pubmed25n0300.xml.gz']

# %%
# Download
base_url = f"https://{ftp_host}{ftp_dir}/"
for fname in tqdm(gz_files):
    # print(f"Downloading: {fname}")
    url = base_url + fname
    dest = os.path.join(download_dir, fname)
    urlretrieve(url, dest)

print(f"\n✅ Downloaded {len(gz_files)} files to `{download_dir}/`")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:51<00:00,  5.79it/s]
# ✅ Downloaded 300 files to `../data/pubmed_baseline/`

# %%
min_words = 20
max_workers = 4

def parse_and_filter(file_path):
    rows = []
    try:
        with gzip.open(file_path, 'rb') as f:
            tree = ET.parse(f)
        root = tree.getroot()
        for article in root.findall(".//PubmedArticle"):
            pmid = article.findtext(".//PMID")
            lang = article.findtext(".//Language")
            title = article.findtext(".//ArticleTitle")
            abstract = article.findtext(".//Abstract/AbstractText")

            if not (pmid and title and abstract):
                continue
            if lang and lang.strip().lower() != "eng":
                continue
            if len(abstract.split()) < min_words:
                continue

            rows.append((pmid.strip(), title.strip(), abstract.strip()))
    except Exception as e:
        print(f"Error in {file_path}: {e}")
    return rows

def process_files_in_chunks(gz_dir, output_csv, workers=4):
    files = sorted([os.path.join(gz_dir, f) for f in os.listdir(gz_dir) if f.endswith(".gz")])

    # Initialize CSV with header
    with open(output_csv, "w", newline='', encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["pmid", "title", "abstract"])

    # Process files in parallel
    with ProcessPoolExecutor(max_workers=workers) as executor:
        futures = {executor.submit(parse_and_filter, f): f for f in files}
        for future in as_completed(futures):
            rows = future.result()
            if rows:
                with open(output_csv, "a", newline='', encoding="utf-8") as f:
                    writer = csv.writer(f)
                    writer.writerows(rows)

# Run it
process_files_in_chunks(gz_dir, output_csv, workers=max_workers)
print(f"\n✅ Data written incrementally to: {output_csv}")
# Out:
# ✅ Data written incrementally to: ../data/pubmed_baseline/pubmed_filtered.csv

# %%
df = pd.read_csv(output_csv)

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
train_df = df.loc[:train_size -1, :]
test_df = df.loc[train_size:train_size + test_size - 1, :]
val_df = df.loc[train_size + test_size: train_size + test_size + val_size - 1, :]

# %%
train_df.shape, test_df.shape, val_df.shape
# Out:
# ((1000000, 3), (3000, 3), (200, 3))

# %%
train_df.to_csv(train_csv, index=False)
test_df.to_csv(test_csv, index=False)
val_df.to_csv(val_csv, index=False)

# %%
train_df.head()
# Out:
#       pmid                                              title  \
# 0  2712356  Membrane relationships in murine Meissner corp...
# 1  8979397  Two-dimensional protein patterns of Arabidopsi...
# 2  1462207  Pathoanatomy of lumbar disc herniation as demo...
# 3  1807731  An innovative method of teaching Advanced Card...
# 4  3207648  The distribution of CA 125 in the reproductive...
#
#                                             abstract
# 0  Mechanoreceptive sensory corpuscles (murine Me...
# 1  In order to detect gene products involved in A...
# 2  Computed tomography/discography was performed ...
# 3  A demonstration and discussion of the effectiv...
# 4  Investigation of serum and tissue homogenates ...

# %%
def tokenize_dataset(tokenizer, data_df):
    dataset = Dataset.from_pandas(data_df)
    def tokenize(example):
        text = f"<s>{example['title']}\n{example['abstract']}</s>"
        return tokenizer(text, truncation=True, padding="max_length", max_length=max_len)
    dataset = dataset.map(tokenize, batched=True)
    return dataset
